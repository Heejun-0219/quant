# %%
import FinanceDataReader as fdr
import pandas as pd
import time, os, glob
import datetime

# %%
# today Stock List
markets = ['krx', 'kospi','kosdaq','konex', 'krx-marcap', 'krx-desc', 'kospi-desc', 'kosdaq-desc', 'konex-desc', 'krx-delisting', 'krx-administrative', 'krx-marcap', 'nasdaq', 'nyse', 'amex', 'sse', 'szse', 'hkex', 'tse', 'hose', 's&p500', 'etf/kr']
docPosition = "market_data/"
today = datetime.date.today()

def todayMarketData():
    for market in markets:
        marketName = market
        if market.find('/'):
            marketName = market.replace('/', '-')
        
        fileName = docPosition + "{}-{}.csv".format(marketName, today)
        if os.path.isfile(fileName) == False:
            try:
                if marketName == 'etf-kr':
                    for file in glob.glob(docPosition + marketName + "-[0-9]*"):
                        print(f'delete file {file}')
                        os.remove(file)
                
                for file in glob.glob(docPosition + market + "-[0-9]*"):
                    print(f'delete file {file}')
                    os.remove(file)
            except FileNotFoundError:
                print(f'file not found')
            except PermissionError:
                print(f'permission denied')
            
            df = fdr.StockListing(market=market)
            print(fileName)
            df.to_csv(fileName)

# %%
df = fdr.DataReader("005930")
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2000-02-14   5600   5660   5340   5380    882889       NaN
# 2000-02-15   5380   5420   5140   5200    766393 -0.033457
# 2000-02-16   5180   5200   4780   5000   1462389 -0.038462
# 2000-02-17   4939   5099   4910   5080   1303738  0.016000
# 2000-02-18   5370   5630   5160   5300   2175083  0.043307
# ...           ...    ...    ...    ...       ...       ...
# 2024-05-30  74800  75200  73500  73500  28551273 -0.022606
# 2024-05-31  74500  74700  73500  73500  26198776  0.000000
# 2024-06-03  74400  76400  74200  75700  15706268  0.029932
# 2024-06-04  74900  76100  74900  75300  14098053 -0.005284
# 2024-06-05  78000  78000  76800  77400  23010088  0.027888
#
# [6000 rows x 6 columns]

# %%
df = fdr.DataReader("000660")
df
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2000-02-14  422037  428907  408296  410259   9164960       NaN
# 2000-02-15  418111  425963  404370  419092   8521020  0.021530
# 2000-02-16  419093  422037  390630  410259   9506460 -0.021077
# 2000-02-17  392593  402407  388667  398481  10655220 -0.028709
# 2000-02-18  396519  409278  393574  398481  10465220  0.000000
# ...            ...     ...     ...     ...       ...       ...
# 2024-05-30  202500  202500  195700  195700   2402236 -0.033580
# 2024-05-31  194400  195200  188200  189200   5958829 -0.033214
# 2024-06-03  189500  194600  188200  194200   2982443  0.026427
# 2024-06-04  196400  196500  192900  193300   1996780 -0.004634
# 2024-06-05  189400  195200  188800  193700   2700257  0.002069
#
# [6000 rows x 6 columns]

# %%
df = fdr.DataReader("000660", start='2001', end='2023-10-1')
df
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2001-01-02   76556   89904   76556   89118  19790590  0.127947
# 2001-01-03   86174   93241   84800   89511  29071000  0.004410
# 2001-01-04  102859  102859   99522  102859  23582200  0.149121
# 2001-01-05  105019  118170  102859  118170  29973110  0.148854
# 2001-01-08  117778  133089  114637  120525  27148680  0.019929
# ...            ...     ...     ...     ...       ...       ...
# 2023-09-21  116000  116900  114100  116500   3151900 -0.012712
# 2023-09-22  114300  117300  114200  117300   2938386  0.006867
# 2023-09-25  115900  117700  115700  117000   2181722 -0.002558
# 2023-09-26  117000  117200  113300  115000   3237819 -0.017094
# 2023-09-27  113000  115200  112300  114700   3060751 -0.002609
#
# [5622 rows x 6 columns]

# %%
stocks = fdr.StockListing('krx')
stocks
# Out:
#         Code        ISU_CD      Name  Market         Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자   KOSPI                77400          1
# 1     000660  KR7000660001    SK하이닉스   KOSPI               193700          1
# 2     373220  KR7373220003  LG에너지솔루션   KOSPI               351500          1
# 3     005380  KR7005380001       현대차   KOSPI               264000          1
# 4     207940  KR7207940008  삼성바이오로직스   KOSPI               760000          1
# ...      ...           ...       ...     ...          ...     ...        ...
# 2805  266170  KR7266170000   뿌리깊은나무들   KONEX        일반기업부     431          1
# 2806  217320  KR7217320001       썬테크   KONEX        일반기업부    2600          0
# 2807  148140  KR7148140007      비디아이  KOSDAQ  관리종목(소속부없음)     120          1
# 2808  245450  KR7245450002    씨앤에스링크   KONEX        일반기업부    1479          2
# 2809  308700  KR7308700004       테크엔   KONEX        일반기업부     199          0
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# 0        2100         2.79   78000   78000   76800  23177968  1794236853400
# 1         400         0.21  189400  195200  188800   2709631   519753179900
# 2       15000         4.46  339000  359500  338000    395864   139132029000
# 3        5000         1.93  261000  267500  256500    882084   232519202875
# 4        7000         0.93  757000  774000  751000     64528    49185224000
# ...       ...          ...     ...     ...     ...       ...            ...
# 2805        1         0.23     434     434     366        15           6335
# 2806        0         0.00       0       0       0         0              0
# 2807       11        10.09     192     382     100   7564504     1754186531
# 2808      -10        -0.67    1479    1479    1479        31          45849
# 2809        0         0.00       0       0       0         0              0
#
#                Marcap      Stocks MarketId
# 0     462061169370000  5969782550      STK
# 1     141014058100500   728002365      STK
# 2      82251000000000   234000000      STK
# 3      55285874424000   209416191      STK
# 4      54092240000000    71174000      STK
# ...               ...         ...      ...
# 2805       2841267077     6592267      KNX
# 2806       2730000000     1050000      KNX
# 2807       2356420680    19636839      KSQ
# 2808       2336760840     1579960      KNX
# 2809        796000000     4000000      KNX
#
# [2810 rows x 17 columns]

# %%
stockCode = stocks['Code']
stockCode
# Out:
# 0       005930
# 1       000660
# 2       373220
# 3       005380
# 4       207940
#          ...
# 2805    266170
# 2806    217320
# 2807    148140
# 2808    245450
# 2809    308700
# Name: Code, Length: 2810, dtype: object

# %%
stockName = '삼성전자'

if stockName in stocks['Name'].values:
    stockSymbol = stocks[stocks['Name'] == stockName]['Code'].values[0]
    
df = fdr.DataReader(stockSymbol, start='2020')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2024-05-30  74800  75200  73500  73500  28551273 -0.022606
# 2024-05-31  74500  74700  73500  73500  26198776  0.000000
# 2024-06-03  74400  76400  74200  75700  15706268  0.029932
# 2024-06-04  74900  76100  74900  75300  14098053 -0.005284
# 2024-06-05  78000  78000  76800  77400  23010088  0.027888
#
# [1092 rows x 6 columns]

# %%
stocks[stocks['Name'] == stockName]['Code'].values[0]
# Out:
# '005930'

# %%
def stockDataReader_fn(market, stockName, startDate = None, endDate = None):
    fileName = docPosition + "{}-{}.csv".format(market, today)
    if os.path.isfile(fileName) == False:
        raise Exception('do not exist market data file')
    df = pd.read_csv(fileName)
    
    if stockName in df['Name'].values:
        code = df[df['Name'] == stockName]['Code'].values[0]
    else:
        raise Exception('do not exist market data code')

    stockData = fdr.DataReader(code, start=startDate, end=endDate)
    return stockData

# %%
todayMarketData()
stockData = stockDataReader_fn(market='krx', stockName='삼성전자')
print(stockData.tail())
# Out:
# delete file market_data/krx-2024-06-04.csv
# market_data/krx-2024-06-06.csv
# delete file market_data/kospi-2024-06-04.csv
# market_data/kospi-2024-06-06.csv
# delete file market_data/kosdaq-2024-06-04.csv
# market_data/kosdaq-2024-06-06.csv
# delete file market_data/konex-2024-06-04.csv
# market_data/konex-2024-06-06.csv
# delete file market_data/krx-marcap-2024-06-04.csv
# market_data/krx-marcap-2024-06-06.csv
# delete file market_data/krx-desc-2024-06-04.csv
# market_data/krx-desc-2024-06-06.csv
# delete file market_data/kospi-desc-2024-06-04.csv
# market_data/kospi-desc-2024-06-06.csv
# delete file market_data/kosdaq-desc-2024-06-04.csv
# market_data/kosdaq-desc-2024-06-06.csv
# delete file market_data/konex-desc-2024-06-04.csv
# market_data/konex-desc-2024-06-06.csv
# delete file market_data/krx-delisting-2024-06-04.csv
# market_data/krx-delisting-2024-06-06.csv
# delete file market_data/krx-administrative-2024-06-04.csv
# market_data/krx-administrative-2024-06-06.csv
# delete file market_data/nasdaq-2024-06-04.csv
# 100%|██████████| 3762/3762 [00:05<00:00, 650.44it/s]
# market_data/nasdaq-2024-06-06.csv
# delete file market_data/nyse-2024-06-04.csv
# 100%|██████████| 2799/2799 [00:03<00:00, 797.68it/s]
# market_data/nyse-2024-06-06.csv
# delete file market_data/amex-2024-06-04.csv
# 100%|██████████| 327/327 [00:00<00:00, 1005.71it/s]
# market_data/amex-2024-06-06.csv
# delete file market_data/sse-2024-06-04.csv
# 100%|██████████| 1563/1563 [00:01<00:00, 1180.89it/s]
# market_data/sse-2024-06-06.csv
# delete file market_data/szse-2024-06-04.csv
# 100%|██████████| 1808/1808 [00:01<00:00, 1131.14it/s]
# /Users/kimheejune/miniconda3/lib/python3.12/site-packages/FinanceDataReader/naver/listing.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat(df_list)
# market_data/szse-2024-06-06.csv
# delete file market_data/hkex-2024-06-04.csv
# 100%|██████████| 2683/2683 [00:02<00:00, 1232.43it/s]
# market_data/hkex-2024-06-06.csv
# delete file market_data/tse-2024-06-04.csv
# 100%|██████████| 4009/4009 [00:03<00:00, 1144.02it/s]
# market_data/tse-2024-06-06.csv
# delete file market_data/hose-2024-06-04.csv
# 100%|██████████| 398/398 [00:00<00:00, 1252.04it/s]
# market_data/hose-2024-06-06.csv
# delete file market_data/s&p500-2024-06-04.csv
# market_data/s&p500-2024-06-06.csv
# delete file market_data/etf-kr-2024-06-04.csv
# market_data/etf-kr-2024-06-06.csv
#              Open   High    Low  Close    Volume    Change
# Date
# 2024-05-30  74800  75200  73500  73500  28551273 -0.022606
# 2024-05-31  74500  74700  73500  73500  26198776  0.000000
# 2024-06-03  74400  76400  74200  75700  15706268  0.029932
# 2024-06-04  74900  76100  74900  75300  14098053 -0.005284
# 2024-06-05  78000  78000  76800  77400  23010088  0.027888
